नेपालमा बचत तथा ऋण सहकारी संस्थाहरुको प्रभावकारी अनुगमनको अभावमा जोखिम भएको भन्दै आलोचना भइरहेका बेला एक्सेस ब्राण्डले सहकारीप्रतिको विश्वास बढाउने जनउत्थान साकोसका व्यवस्थापक रनबहादुर थापाले बताए ।

सुरुको वर्ष चार वटा सहकारी मात्र यो ब्राण्ड पाउन आवेदन दिएकामा हरेक वर्ष संख्या बढ्दै गएको नेफ्स्कुनका केन्द्रीय सदस्य कृष्ण नेपालले बताए ।


'''

# %% [markdown]
# # Splitting the document into tokens

# %%
tokens=text.split()

# %%
print(tokens)
# Out:
# ['२४', 'सहकारीलाई', 'एशियाली', 'मापदण्डको', 'एक्सेस', 'ब्राण्ड', 'अनलाइनखबर', '२०७६', 'भदौ', '१८', 'गते', '१९:२९', 'मा', 'प्रकाशित', '0', 'प्रतिक्रिया', '१८', 'भदौ,', 'बुटवल', '।', 'प्रदेश', '५', 'का', 'चारसहित', '२४', 'वटा', 'वचत', 'तथा', 'ऋण', 'सहकारी', 'संस्था', '(साकोस)', 'ले', 'एशियाली', 'मापदण्डको', 'एक्सेस', 'ब्राण्ड', 'पाएका', 'छन्', '।', 'रजत', 'स्तरको', 'एक्सेस', 'ब्राण्ड', 'पाउनेमा', 'रुपन्देहीका', 'एकसहित', 'आठ', 'वटा', 'र', 'कास्य', 'स्तरको', 'एक्सेस', 'ब्राण्ड', 'पाउने', '१६', 'वटा', 'साकोस', 'रहेका', 'छन्', '।', 'जसमध्ये', 'प्रदेश', '५', 'को', 'रुपन्देहीका', 'जनउत्थानले', 'रजत', 'स्तरको', 'र', 'कोलिय', 'देवदहले', 'कास्य', 'स्तरको', 'एक्सेस', 'ब्राण्ड', 'प्राप्त', 'गरेका', 'छन्', '।', 'यस्तै', 'पश्चिम', 'नवलपरासीको', 'ग्रामीण', 'साकोस', 'र', 'बर्दियाको', 'सिको', 'साकोसले', 'रजत', 'स्तरको', 'एक्सेस', 'ब्राण्ड', 'पाएका', 'छन्', '।', 'रजत', 'स्तरको', 'एक्सेस', 'ब्राण्ड', 'पाउनेहरुमा', 'काभ्रेपलाञ्चोकका', 'विन्धबासिनी', 'र', 'सामुदायिक,', 'दोलखाका', 'जनसचेतन', 'र', 'मिलिजुल
# ...

# %% [markdown]
# # Doing some text cleaning like punctuations and stopwords removing

# %%
import string
punctuations= list(string.punctuation)
print(punctuations)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %% [markdown]
# # Adding punctuations

# %%
punctuations.append('।')

# %%
print(punctuations)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '।']

# %% [markdown]
# # Token cleaning by removing punctuations

# %%
cleaned_tokens=[w for w in tokens if w not in punctuations]

# %%
cleaned_tokens
# Out:
# ['२४',
#  'सहकारीलाई',
#  'एशियाली',
#  'मापदण्डको',
#  'एक्सेस',
#  'ब्राण्ड',
#  'अनलाइनखबर',
#  '२०७६',
#  'भदौ',
#  '१८',
#  'गते',
#  '१९:२९',
#  'मा',
#  'प्रकाशित',
#  '0',
#  'प्रतिक्रिया',
#  '१८',
#  'भदौ,',
#  'बुटवल',
#  'प्रदेश',
#  '५',
#  'का',
#  'चारसहित',
#  '२४',
#  'वटा',
#  'वचत',
#  'तथा',
#  'ऋण',
#  'सहकारी',
#  'संस्था',
#  '(साकोस)',
#  'ले',
#  'एशियाली',
#  'मापदण्डको',
#  'एक्सेस',
#  'ब्राण्ड',
#  'पाएका',
#  'छन्',
#  'रजत',
#  'स्तरको',
#  'एक्सेस',
#  'ब्राण्ड',
#  'पाउनेमा',
#  'रुपन्देहीका',
#  'एकसहित',
#  'आठ',
#  'वटा',
#  'र',
#  'कास्य',
#  'स्तरको',
#  'एक्सेस',
#  'ब्राण्ड',
#  'पाउने',
#  '१६',
#  'वटा',
#  'साकोस',
#  'रहेका',
#  'छन्',
#  'जसमध्ये',
#  'प्रदेश',
#  '५',
#  'को',
#  'रुपन्देहीका',
#  'जनउत्थानले',
#  'रजत',
#  'स्तरको',
#  'र',
#  'कोलिय',
#  'देवदहले',
#  'कास्य',
#  'स्तरको',
#  'एक्सेस',
#  'ब्राण्ड',
#  'प्राप्त',
#  'गरेका',
#  'छन्',
#  'यस्तै',
#  'पश्चिम',
#  'नवलपरासीको',
#  'ग्रामीण',
#  'साकोस',
#  'र',
# ...

# %%
from nltk.corpus import indian
from nltk.tag import tnt

# %%
indian.fileids()
# Out:
# ['bangla.pos', 'hindi.pos', 'marathi.pos', 'nepali.pos', 'telugu.pos']

# %%
for i in indian.fileids():
    print(i, len(indian.raw(i)))
# Out:
# bangla.pos 118283
# hindi.pos 103087
# marathi.pos 229853
# nepali.pos 1309
# telugu.pos 138273

# %%
for i in indian.fileids():
    print(i, len(indian.sents(i)))
# Out:
# bangla.pos 896
# hindi.pos 540
# marathi.pos 1197
# nepali.pos 5
# telugu.pos 994

# %%
nepali_sent = indian.sents('nepali.pos')

# %%
for h_sent in nepali_sent:
    print(h_sent)
# Out:
# ['६१', 'वर्षीय', 'पियरे', 'भिन्केन', 'नोभेम्बर', '२९', 'बाट', 'सल्लाहकार', 'को', 'रूप', 'मा', 'सञ्चालक', 'समिति', 'मा', 'आउनुहुनेछ', '।']
# ['श्री', 'भिन्केन', 'डच', 'प्रकाशन', 'समूह', 'एल्सेभियर', 'एन.भी.', 'को', 'अध्यक्ष', 'हुनुहुन्छ', '।']
# ['कन्सोलिडेटिड', 'गोल्ड', 'फिल्ड्स', 'पीएलसी', 'का', 'पूर्व', 'सभापति', '५५', 'वर्षीय', 'रूडोल्फ', 'अग्न्यु', 'लाई', 'यस', 'ब्रिटिस', 'औद्योगिक', 'समूह', 'को', 'सल्लाहकार', 'को', 'रूप', 'मा', 'मनोनयन', 'गरिएको', 'थियो', '।']
# ['एकताका', 'केन्ट', 'चुरोट', 'को', 'फिल्टर', 'बनाउन', 'प्रयोग', 'भएको', 'एक', 'प्रकार', 'को', 'अस्बेस्टोस', 'तीस', 'वर्ष', 'भन्दा', 'अगाडि', 'यस', 'को', 'सम्पर्क', 'मा', 'आएका', 'कामदार', 'हरू', 'को', 'समूह', 'मा', 'क्यान्सर', 'बाट', 'मृत्यु', 'हुनेको', 'उच्च', 'प्रतिशत', 'को', 'कारण', 'बनेको', 'छ', ',', 'अनुसन्धाता', 'हरू', 'ले', 'जानकारी', 'दिए', '।']
# ...

# %% [markdown]
# # creating a file

# %%
it = open("neapli_corpus_sents.txt",'w',encoding="utf-8")  
for h_sent in nepali_sent:
    it.write(" ".join(h_sent))

# %% [markdown]
# # Accessing the words in corpus

# %%
hin_word = indian.words('nepali.pos')
hin_word
# Out:
# ['६१', 'वर्षीय', 'पियरे', 'भिन्केन', 'नोभेम्बर', '२९', ...]

# %% [markdown]
# # Accessing the POS tagged sentences from a corpora

# %%
nepali_pos_sen = indian.tagged_sents('nepali.pos')
for sent in nepali_pos_sen:
    print(sent)
# Out:
# [('६१', 'CD'), ('वर्षीय', 'JJ'), ('पियरे', 'NNP'), ('भिन्केन', 'NNP'), ('नोभेम्बर', 'NNP'), ('२९', 'CD'), ('बाट', 'POP'), ('सल्लाहकार', 'NN'), ('को', 'PKO'), ('रूप', 'NN'), ('मा', 'POP'), ('सञ्चालक', 'NN'), ('समिति', 'NN'), ('मा', 'POP'), ('आउनुहुनेछ', 'VBX'), ('।', 'YF')]
# [('श्री', 'NN'), ('भिन्केन', 'NNP'), ('डच', 'NNP'), ('प्रकाशन', 'NN'), ('समूह', 'NN'), ('एल्सेभियर', 'NNP'), ('एन.भी.', 'FB'), ('को', 'PKO'), ('अध्यक्ष', 'NN'), ('हुनुहुन्छ', 'VBF'), ('।', 'YF')]
# [('कन्सोलिडेटिड', 'NNP'), ('गोल्ड', 'NN'), ('फिल्ड्स', 'NN'), ('पीएलसी', 'NNP'), ('का', 'PKO'), ('पूर्व', 'JJ'), ('सभापति', 'NN'), ('५५', 'CD'), ('वर्षीय', 'JJ'), ('रूडोल्फ', 'NNP'), ('अग्न्यु', 'NNP'), ('लाई', 'PLAI'), ('यस', 'DUM'), ('ब्रिटिस', 'NNP'), ('औद्योगिक', 'JJ'), ('समूह', 'NN'), ('को', 'PKO'), ('सल्लाहकार', 'NN'), ('को', 'PKO'), ('रूप', 'NN'), ('मा', 'POP'), ('मनोनयन', 'NN'), ('गरिएको', 'VBKO'), ('थियो', 'VBX'), ('।', 'YF')]
# ...
